# %% [markdown]
# #### 공지사항

# %% [markdown]
# API 키(env 파일)가 필요한 경우, 각자 다운 받은 후 push 할 때, 제외시키길 권장함.
# 보안 문제로 인해 git push가 불가능함

# %% [markdown]
# #### 필요한 라이브러리 설치

# %%
# 안될경우 Terminal 창을 VS Code에서 실행해서 직접 하나씩 입력해서 설치 권창창
pip install openai
pip install django-environ
pip install azure-storage-blob

# %% [markdown]
# #### gpt-3o-mini(test)+ DALL-E 3 + 통합 코드 이미지 파일 로컬 / Azure Blob Storage 저장

# %%
import os 
import re 
import time
import requests 
import environ
from pathlib import Path
from openai import AzureOpenAI

from azure.storage.blob import BlobServiceClient, BlobClient # Azure Blob Storage 저장을 위한 lib
  
# .env 파일 로드 (모든 환경 변수 로드)
env = environ.Env()
environ.Env.read_env(env_file=".env")  
  
# Azure OpenAI 환경 변수 설정  
AZURE_3OMINI_ENDPOINT = env("AZURE_3OMINI_ENDPOINT")  
AZURE_3OMINI_API_KEY = env("AZURE_3OMINI_API_KEY")  
AZURE_3OMINI_API_VERSION ="2024-12-01-preview"
  
if not AZURE_3OMINI_ENDPOINT or not AZURE_3OMINI_API_KEY:  
    raise ValueError("환경 변수가 올바르게 설정되지 않았습니다. .env 파일을 확인하세요.")  
  

GPT_CLIENT = AzureOpenAI(
    azure_endpoint=AZURE_3OMINI_ENDPOINT,
    api_key=AZURE_3OMINI_API_KEY,
    api_version=AZURE_3OMINI_API_VERSION
)


def generate_prompt_with_gpt3o(user_input):
    try:
        print("GPT-3o-mini를 사용해 프롬프트를 생성합니다...")

        response = GPT_CLIENT.chat.completions.create(
            model="team6-o3-mini",
            messages=[
                {"role": "system", "content": """You are an expert in converting user's natural language descriptions into DALL-E image generation prompts.
            Please generate prompts according to the following guidelines:

            ##Main Guidelines

            1. Carefully analyze the user's description to identify key elements.
            2. Use clear and specific language to write the prompt.
            3. Include details such as the main subject, style, composition, color, and lighting of the image.
            4. Appro-priately utilize artistic references or cultural elements to enrich the prompt.
            5. Add instructions about image quality or resolution if necessary.
            6. Evaluate if the user's request might violate DALL-E's content policy. If there's a possibility of violation, include a message in the user's original language: "This content may be blocked by DALL-E. Please try a different approach." and explain why blocked.
            7. Always provide the prompt in English, regardless of the language used in the user's request.

            ##Prompt Structure

            - Specify the main subject first, then add details.
            - Use adjectives and adverbs effectively to convey the mood and style of the image.
            - Specify the composition or perspective of the image if needed.

            ##Precautions

            - Do not directly mention copyrighted characters or brands.
            - Avoid violent or inappropriate content.
            - Avoid overly complex or ambiguous descriptions, maintain clarity.
            - Avoid words related to violence, adult content, gore, politics, or drugs.
            - Do not use names of real people.
            - Avoid directly mentioning specific body parts.

            ##Using Alternative Expressions

            Consider DALL-E's strict content policy and use visual synonyms with similar meanings to prohibited words. Examples:

            - "shooting star" → "meteor" or "falling star"
            - "exploding" → "bursting" or "expanding"

            ##Example Prompt Format

            "[Style/mood] image of [main subject]. [Detailed description]. [Composition/perspective]. [Color/lighting information]." Follow these guidelines to convert the user's description into a DALL-E-appropriate prompt. The prompt should be creative yet easy for AI to understand. If there's a possibility of content policy violation, notify the user and suggest alternatives."""},
                {"role": "user", "content": user_input}
            ]
        )

        if response.choices and len(response.choices) > 0:
            return response.choices[0].message.content
        else:
            print("응답을 생성하지 못했습니다.")
            return None

    except Exception as e:
        print("GPT-3o-mini 호출 중 예외 발생:", str(e))
        return None
    
# DALL-E 클라이언트 초기화  
DALLE_CLIENT = AzureOpenAI(  
    azure_endpoint=env("AZURE_DALLE_ENDPOINT"),  
    api_key=env("AZURE_DALLE_API_KEY"),  
    api_version=env("AZURE_DALLE_API_VERSION")  
)  

def generate_image_with_dalle(prompt):  
    """DALL-E를 사용해 이미지를 생성"""  
    try:  
        print("DALL-E를 사용해 이미지를 생성합니다...")  
  
        # DALL-E API 호출  
        result = DALLE_CLIENT.images.generate(  
            model="dall-e-3",  # 사용할 DALL-E 모델  
            prompt=prompt,    # 생성할 이미지에 대한 프롬프트  
            n=1               # 생성할 이미지 개수  
        )  
  
        # 결과 처리  
        if result and result.data:  
            image_url = result.data[0].url  
            print("DALL-E 호출 성공! 생성된 이미지 URL:", image_url)  

            # 이미지 다운로드 및 저장
            save_image(image_url, prompt)
            
            return image_url  
        else:  
            print("DALL-E 호출 실패: 결과가 비어 있습니다.")  
            return None  
    except Exception as e:  
        print("DALL-E 호출 중 예외 발생:", str(e))  
        return None  
    
def save_image(image_url, prompt):
    """이미지를 다운로드하여 로컬에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()  

        # 이미지 폴더 생성
        os.makedirs("images", exist_ok=True)

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = os.path.join("images", f"{sanitized_filename}.png")

        with open(filename, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"이미지가 저장되었습니다: {filename}")

    except Exception as e:
        print(f"이미지 저장 중 오류 발생: {e}")

# 환경 변수 가져오기
account_name = env("STORAGE_ACCOUNT_NAME")  # 스토리지 계정명
account_key = env("STORAGE_ACCOUNT_KEY")  # 스토리지 계정 키
container_name = env("AI_CONTAINER_NAME")  # 컨테이너 이름

# Account Key를 사용하여 BlobServiceClient 생성
blob_service_client = BlobServiceClient(
    f"https://{account_name}.blob.core.windows.net",
    credential=account_key
)

def save_image_to_blob_storage(image_url, prompt):
    """이미지를 다운로드하여 Azure Blob Storage에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = f"{sanitized_filename}.png"

        # Blob Client 생성
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=filename)

        # 이미지 데이터 업로드 (파일 덮어쓰기 추가)
        blob_client.upload_blob(response.content, overwrite=True)

        # print(f"이미지가 Azure Blob Storage에 저장되었습니다: {filename}")

    except requests.exceptions.RequestException as req_err:
        print(f"이미지 다운로드 오류: {req_err}")

    except Exception as e:
        print(f"Azure Blob Storage에 이미지 저장 중 오류 발생: {e}")

def main():  
    """전체 워크플로 실행"""  
    user_input = input("이미지 생성 아이디어를 입력하세요: ").strip()  
    if not user_input:  
        print("입력값이 비어 있습니다. 유효한 입력값을 제공합니다.")  
        return  
  
    # Step 1: GPT-4o-mini를 사용해 프롬프트 생성  
    prompt = generate_prompt_with_gpt3o(user_input)  
    if not prompt:  
        print("프롬프트 생성 실패. 워크플로를 종료합니다.")  
        return  
  
    # Step 2: DALL-E를 사용해 이미지 생성  
    image_url = generate_image_with_dalle(prompt)  
    if not image_url:  
        print("이미지 생성 실패. 워크플로를 종료합니다.")  
        return  
    
    # Step 3: Azure Blob Storage에 이미지 저장
    if image_url:
        save_image_to_blob_storage(image_url, prompt)
  
    print("\n=== 최종 결과 ===")
    print(f"생성된 이미지가 'images/' 폴더에 저장되었습니다.")   
    print(f"생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.")  
  
  
if __name__ == "__main__":  
    main()
# Out:
# GPT-3o-mini를 사용해 프롬프트를 생성합니다...
# DALL-E를 사용해 이미지를 생성합니다...
# DALL-E 호출 성공! 생성된 이미지 URL: https://dalleproduse.blob.core.windows.net/private/images/4b208bd9-92a2-4f77-a515-57fd70007216/generated_00.png?se=2025-02-13T01%3A43%3A03Z&sig=45RoVDQqGd3YUgh0GKGNxMBUDR45bMcU3%2FXS3%2Biyu2E%3D&ske=2025-02-18T01%3A15%3A33Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2025-02-11T01%3A15%3A33Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02
# 이미지가 저장되었습니다: images\A majestic reindeer standing g.png
#
# === 최종 결과 ===
# 생성된 이미지가 'images/' 폴더에 저장되었습니다.
# 생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.

# %% [markdown]
# #### AI 큐레이션 - 이미지 캡션 기능

# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# Collecting azure-cognitiveservices-vision-computervision
#   Downloading azure_cognitiveservices_vision_computervision-0.9.1-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting msrest>=0.6.21 (from azure-cognitiveservices-vision-computervision)
#   Using cached msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting azure-common~=1.1 (from azure-cognitiveservices-vision-computervision)
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (1.32.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2024.8.30)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (0.7.2)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests~=2.16 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\bongs\appdata\roaming\python\python311\site-packages (from azure-core>=1.24.0->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\bongs\appdata\roaming\python\python311\site-packages (from azure-core>=1.24.0->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bongs\appdata\local\programs\python\python311\lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2.2.3)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading azure_cognitiveservices_vision_computervision-0.9.1-py2.py3-none-any.whl (36 kB)
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: azure-common, oauthlib, requests-oauthlib, msrest, azure-cognitiveservices-vision-computervision
# Successfully installed azure-cognitiveservices-vision-computervision-0.9.1 azure-common-1.1.28 msrest-0.7.1 oauthlib-3.2.2 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

# ...existing code...

# .env 파일 로드 (모든 환경 변수 로드)
env = environ.Env()
environ.Env.read_env(env_file=".env")  
  
def get_image_caption_and_tags(image_url):
    AZURE_COMPUTER_VISION_API_KEY = env("AZURE_COMPUTER_VISION_API_KEY")
    AZURE_COMPUTER_VISION_ENDPOINT = env("AZURE_COMPUTER_VISION_ENDPOINT")

    computervision_client = ComputerVisionClient(
        AZURE_COMPUTER_VISION_ENDPOINT,
        CognitiveServicesCredentials(AZURE_COMPUTER_VISION_API_KEY),
    )

    # Analyze the image using the Dense Caption feature
    analysis = computervision_client.describe_image(image_url)

    # Extract the caption information
    captions = []
    if analysis.captions:
        for caption in analysis.captions:
            print("Caption: ", caption.text)
            captions.append(caption.text)
    else:
        captions.append("No caption detected.")

    # Extract the tag information
    tags_result = computervision_client.tag_image(image_url)
    tags = [tag.name for tag in tags_result.tags]
    print("Tags: ", tags)

    return captions, tags


# ...existing code...
# image_url = "https://imgnews.pstatic.net/image/011/2025/02/05/0004447162_001_20250205215010307.png?type=w860"
# image_url = "https://img1.daumcdn.net/thumb/R1280x0.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/aZCw/image/eeJn2IfiJW6Jmmu4mXFVBGcNcxs.jpg"
# image_url = "https://flexible.img.hani.co.kr/flexible/normal/860/484/imgdb/original/2025/0206/20250206503901.webp"
# image_url = "https://flexible.img.hani.co.kr/flexible/normal/968/645/imgdb/original/2025/0205/20250205503135.webp"
get_image_caption_and_tags(image_url)
# Out:
# Caption:  a military tank firing its cannon
# Tags:  ['outdoor', 'sky', 'weapon', 'pollution', 'smoke', 'military vehicle', 'mortar', 'tank']
# (['a military tank firing its cannon'],
#  ['outdoor',
#   'sky',
#   'weapon',
#   'pollution',
#   'smoke',
#   'military vehicle',
#   'mortar',
#   'tank'])

# %% [markdown]
# #### AI 큐레이션 기능 추가

# %%
import os 
import re 
import time
import requests 
import environ
from pathlib import Path
from openai import AzureOpenAI

from azure.storage.blob import BlobServiceClient, BlobClient # Azure Blob Storage 저장을 위한 lib
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials
  
# .env 파일 로드 (모든 환경 변수 로드)
env = environ.Env()
environ.Env.read_env(env_file=".env")  
  
# Azure OpenAI 환경 변수 설정  
AZURE_3OMINI_ENDPOINT = env("AZURE_3OMINI_ENDPOINT")  
AZURE_3OMINI_API_KEY = env("AZURE_3OMINI_API_KEY")  
AZURE_3OMINI_API_VERSION ="2024-12-01-preview"
  
if not AZURE_3OMINI_ENDPOINT or not AZURE_3OMINI_API_KEY:  
    raise ValueError("환경 변수가 올바르게 설정되지 않았습니다. .env 파일을 확인하세요.")  
  

GPT_CLIENT = AzureOpenAI(
    azure_endpoint=AZURE_3OMINI_ENDPOINT,
    api_key=AZURE_3OMINI_API_KEY,
    api_version=AZURE_3OMINI_API_VERSION
)


def generate_prompt_with_gpt3o(user_input):
    try:
        print("GPT-3o-mini를 사용해 프롬프트를 생성합니다...")

        response = GPT_CLIENT.chat.completions.create(
            model="team6-o3-mini",
            messages=[
                {"role": "system", "content": """You are an expert in converting user's natural language descriptions into DALL-E image generation prompts.
            Please generate prompts according to the following guidelines:

            ##Main Guidelines

            1. Carefully analyze the user's description to identify key elements.
            2. Use clear and specific language to write the prompt.
            3. Include details such as the main subject, style, composition, color, and lighting of the image.
            4. Appro-priately utilize artistic references or cultural elements to enrich the prompt.
            5. Add instructions about image quality or resolution if necessary.
            6. Evaluate if the user's request might violate DALL-E's content policy. If there's a possibility of violation, include a message in the user's original language: "This content may be blocked by DALL-E. Please try a different approach." and explain why blocked.
            7. Always provide the prompt in English, regardless of the language used in the user's request.

            ##Prompt Structure

            - Specify the main subject first, then add details.
            - Use adjectives and adverbs effectively to convey the mood and style of the image.
            - Specify the composition or perspective of the image if needed.

            ##Precautions

            - Do not directly mention copyrighted characters or brands.
            - Avoid violent or inappropriate content.
            - Avoid overly complex or ambiguous descriptions, maintain clarity.
            - Avoid words related to violence, adult content, gore, politics, or drugs.
            - Do not use names of real people.
            - Avoid directly mentioning specific body parts.

            ##Using Alternative Expressions

            Consider DALL-E's strict content policy and use visual synonyms with similar meanings to prohibited words. Examples:

            - "shooting star" → "meteor" or "falling star"
            - "exploding" → "bursting" or "expanding"

            ##Example Prompt Format

            "[Style/mood] image of [main subject]. [Detailed description]. [Composition/perspective]. [Color/lighting information]." Follow these guidelines to convert the user's description into a DALL-E-appropriate prompt. The prompt should be creative yet easy for AI to understand. If there's a possibility of content policy violation, notify the user and suggest alternatives."""},
                {"role": "user", "content": user_input}
            ]
        )

        if response.choices and len(response.choices) > 0:
            return response.choices[0].message.content
        else:
            print("응답을 생성하지 못했습니다.")
            return None

    except Exception as e:
        print("GPT-3o-mini 호출 중 예외 발생:", str(e))
        return None
    
# DALL-E 클라이언트 초기화  
DALLE_CLIENT = AzureOpenAI(  
    azure_endpoint=env("AZURE_DALLE_ENDPOINT"),  
    api_key=env("AZURE_DALLE_API_KEY"),  
    api_version=env("AZURE_DALLE_API_VERSION")  
)  

def generate_image_with_dalle(prompt):  
    """DALL-E를 사용해 이미지를 생성"""  
    try:  
        print("DALL-E를 사용해 이미지를 생성합니다...")  
  
        # DALL-E API 호출  
        result = DALLE_CLIENT.images.generate(  
            model="dall-e-3",  # 사용할 DALL-E 모델  
            prompt=prompt,    # 생성할 이미지에 대한 프롬프트  
            n=1               # 생성할 이미지 개수  
        )  
  
        # 결과 처리  
        if result and result.data:  
            image_url = result.data[0].url  
            print("DALL-E 호출 성공! 생성된 이미지 URL:", image_url)  

            # 이미지 다운로드 및 저장
            save_image(image_url, prompt)
            
            return image_url  
        else:  
            print("DALL-E 호출 실패: 결과가 비어 있습니다.")  
            return None  
    except Exception as e:  
        print("DALL-E 호출 중 예외 발생:", str(e))  
        return None  
    
def save_image(image_url, prompt):
    """이미지를 다운로드하여 로컬에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()  

        # 이미지 폴더 생성
        os.makedirs("images", exist_ok=True)

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = os.path.join("images", f"{sanitized_filename}.png")

        with open(filename, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"이미지가 저장되었습니다: {filename}")

    except Exception as e:
        print(f"이미지 저장 중 오류 발생: {e}")

# 환경 변수 가져오기
account_name = env("STORAGE_ACCOUNT_NAME")  # 스토리지 계정명
account_key = env("STORAGE_ACCOUNT_KEY")  # 스토리지 계정 키
container_name = env("AI_CONTAINER_NAME")  # 컨테이너 이름

# Account Key를 사용하여 BlobServiceClient 생성
blob_service_client = BlobServiceClient(
    f"https://{account_name}.blob.core.windows.net",
    credential=account_key
)

def save_image_to_blob_storage(image_url, prompt):
    """이미지를 다운로드하여 Azure Blob Storage에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = f"{sanitized_filename}.png"

        # Blob Client 생성
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=filename)

        # 이미지 데이터 업로드 (파일 덮어쓰기 추가)
        blob_client.upload_blob(response.content, overwrite=True)

        # print(f"이미지가 Azure Blob Storage에 저장되었습니다: {filename}")

    except requests.exceptions.RequestException as req_err:
        print(f"이미지 다운로드 오류: {req_err}")

    except Exception as e:
        print(f"Azure Blob Storage에 이미지 저장 중 오류 발생: {e}")

def get_image_caption_and_tags(image_url):
    AZURE_COMPUTER_VISION_API_KEY = env("AZURE_COMPUTER_VISION_API_KEY")
    AZURE_COMPUTER_VISION_ENDPOINT = env("AZURE_COMPUTER_VISION_ENDPOINT")

    computervision_client = ComputerVisionClient(
        AZURE_COMPUTER_VISION_ENDPOINT,
        CognitiveServicesCredentials(AZURE_COMPUTER_VISION_API_KEY),
    )

    # Analyze the image using the Dense Caption feature
    analysis = computervision_client.describe_image(image_url)

    # Extract the caption information
    captions = []
    if analysis.captions:
        for caption in analysis.captions:
            print("Caption: ", caption.text)
            captions.append(caption.text)
    else:
        captions.append("No caption detected.")

    # Extract the tag information
    tags_result = computervision_client.tag_image(image_url)
    tags = [tag.name for tag in tags_result.tags]
    print("Tags: ", tags)

    return captions, tags

def generate_ai_curation(user_prompt, captions, tags):
    combined_text = f"프롬프트: {user_prompt}\n이미지 설명: {captions}\n태그: {tags}"
    response = GPT_CLIENT.chat.completions.create(
        model="team6-o3-mini",
        messages=[
            {"role": "system", "content": 
             """You are an art curation expert. Please create a curation based on the input information.\n 
             Please translate the generated curation into Korean and return it."""},
            {"role": "user", "content": combined_text}
        ]
    )

    return response.choices[0].message.content

def main():  
    """전체 워크플로 실행"""  
    user_input = input("이미지 생성 아이디어를 입력하세요: ").strip()  
    if not user_input:  
        print("입력값이 비어 있습니다. 유효한 입력값을 제공합니다.")  
        return  
  
    # Step 1: GPT-o3-mini를 사용해 프롬프트 생성  
    prompt = generate_prompt_with_gpt3o(user_input)  
    if not prompt:  
        print("프롬프트 생성 실패. 워크플로를 종료합니다.")  
        return  
  
    # Step 2: DALL-E를 사용해 이미지 생성  
    image_url = generate_image_with_dalle(prompt)  
    if not image_url:  
        print("이미지 생성 실패. 워크플로를 종료합니다.")  
        return  
    
    # Step 3: Azure Blob Storage에 이미지 저장
    if image_url:
        save_image_to_blob_storage(image_url, prompt)
    
    # Step 4 : Image Captions, Tags 생성
    captions, tags = get_image_caption_and_tags(image_url)

    # Step 5 : AI 큐레이션 생성
    curation = generate_ai_curation(prompt, captions, tags)
    
    print("\n=== 최종 결과 ===")
    print(f"생성된 이미지가 'images/' 폴더에 저장되었습니다.")   
    print(f"생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.")  
    print("\n=== AI 큐레이션 결과 ===")
    print(curation)
  
if __name__ == "__main__":  
    main()
# Out:
# GPT-3o-mini를 사용해 프롬프트를 생성합니다...
# DALL-E를 사용해 이미지를 생성합니다...
# DALL-E 호출 성공! 생성된 이미지 URL: https://dalleproduse.blob.core.windows.net/private/images/2a4fec6f-8cec-42ba-8637-430d9df67547/generated_00.png?se=2025-02-13T02%3A24%3A32Z&sig=so%2FP2rvjI5OMbtLG2AzW5imo2oT50VOMiIaqKCEdA%2Bc%3D&ske=2025-02-19T00%3A35%3A50Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2025-02-12T00%3A35%3A50Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02
# 이미지가 저장되었습니다: images\A traditional landscape featur.png
# Caption:  a bird flying over a cow and a bull
# Tags:  ['animal', 'painting', 'drawing', 'art', 'bird', 'outdoor', 'mammal']
#
# === 최종 결과 ===
# 생성된 이미지가 'images/' 폴더에 저장되었습니다.
# 생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.
#
# === AI 큐레이션 결과 ===
# 이 작품은 전통 동양 미술의 감수성을 그대로 담아낸 풍경화로, 전경에는 위엄 있는 버팔로가 자리잡고 있고 그 위 하늘에는 날아오르는 독수리가 자유로운 기류를 타고 있습니다. 부드럽게 굽이치는 언덕과 고즈넉한 고목, 그리고 구불구불한 강이 어우러진 자연의 섬세한 디테일은 동물과 자연이 만들어내는 생명의 활기를 한층 돋보이게 만들고 있습니다. 작품의 따뜻한 어스톤과 부드러운 붓터치는 고요하면서도 문화적인 분위기를 자아내며, 강렬한 존재감과 함께 평화로운 자연의 조화를 표현합니다.
#
# 또한, 이미지 설명에 나타난 '소와 황소 위를 나는 새'라는 요소는 전통적인 동물 상징성과 함께 자연의 경이로움을 상징하는 독수리의 모습을 재치 있게 결합하여, 관람객으로 하여금 자연의 다양한 요소들이 어우러져 만들어내는 이야기에 몰입하게 합니다. 동물, 회화, 소묘, 예술, 야외 풍경이라는 태그들은 이 작품이 담고 있는 다양한 감성적 및 시각적 요소들을 잘 나타내 줍니다.
#
# 이처럼 작품은 동양의 전통 미술 기법과 자연의 생동감을 결합하여, 고요하면서도 힘 있는 자연의 미와 인간의 문화적 정서를 아우르는 독특한 예술세계를 선보이고 있습니다.

# %% [markdown]
# ##### AI 큐레이션 프롬프트 상세 설명 추가

# %%
import os 
import re 
import time
import requests 
import environ
from pathlib import Path
from openai import AzureOpenAI

from azure.storage.blob import BlobServiceClient, BlobClient # Azure Blob Storage 저장을 위한 lib
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials
  
# .env 파일 로드 (모든 환경 변수 로드)
env = environ.Env()
environ.Env.read_env(env_file=".env")  
  
# Azure OpenAI 환경 변수 설정  
AZURE_3OMINI_ENDPOINT = env("AZURE_3OMINI_ENDPOINT")  
AZURE_3OMINI_API_KEY = env("AZURE_3OMINI_API_KEY")  
AZURE_3OMINI_API_VERSION ="2024-12-01-preview"
  
if not AZURE_3OMINI_ENDPOINT or not AZURE_3OMINI_API_KEY:  
    raise ValueError("환경 변수가 올바르게 설정되지 않았습니다. .env 파일을 확인하세요.")  
  

GPT_CLIENT = AzureOpenAI(
    azure_endpoint=AZURE_3OMINI_ENDPOINT,
    api_key=AZURE_3OMINI_API_KEY,
    api_version=AZURE_3OMINI_API_VERSION
)


def generate_prompt_with_gpt3o(user_input):
    try:
        print("GPT-3o-mini를 사용해 프롬프트를 생성합니다...")

        response = GPT_CLIENT.chat.completions.create(
            model="team6-o3-mini",
            messages=[
                {"role": "system", "content": """You are an expert in converting user's natural language descriptions into DALL-E image generation prompts.
            Please generate prompts according to the following guidelines:

            ##Main Guidelines

            1. Carefully analyze the user's description to identify key elements.
            2. Use clear and specific language to write the prompt.
            3. Include details such as the main subject, style, composition, color, and lighting of the image.
            4. Appro-priately utilize artistic references or cultural elements to enrich the prompt.
            5. Add instructions about image quality or resolution if necessary.
            6. Evaluate if the user's request might violate DALL-E's content policy. If there's a possibility of violation, include a message in the user's original language: "This content may be blocked by DALL-E. Please try a different approach." and explain why blocked.
            7. Always provide the prompt in English, regardless of the language used in the user's request.

            ##Prompt Structure

            - Specify the main subject first, then add details.
            - Use adjectives and adverbs effectively to convey the mood and style of the image.
            - Specify the composition or perspective of the image if needed.

            ##Precautions

            - Do not directly mention copyrighted characters or brands.
            - Avoid violent or inappropriate content.
            - Avoid overly complex or ambiguous descriptions, maintain clarity.
            - Avoid words related to violence, adult content, gore, politics, or drugs.
            - Do not use names of real people.
            - Avoid directly mentioning specific body parts.

            ##Using Alternative Expressions

            Consider DALL-E's strict content policy and use visual synonyms with similar meanings to prohibited words. Examples:

            - "shooting star" → "meteor" or "falling star"
            - "exploding" → "bursting" or "expanding"

            ##Example Prompt Format

            "[Style/mood] image of [main subject]. [Detailed description]. [Composition/perspective]. [Color/lighting information]." Follow these guidelines to convert the user's description into a DALL-E-appropriate prompt. The prompt should be creative yet easy for AI to understand. If there's a possibility of content policy violation, notify the user and suggest alternatives."""},
                {"role": "user", "content": user_input}
            ]
        )

        if response.choices and len(response.choices) > 0:
            return response.choices[0].message.content
        else:
            print("응답을 생성하지 못했습니다.")
            return None

    except Exception as e:
        print("GPT-3o-mini 호출 중 예외 발생:", str(e))
        return None
    
# DALL-E 클라이언트 초기화  
DALLE_CLIENT = AzureOpenAI(  
    azure_endpoint=env("AZURE_DALLE_ENDPOINT"),  
    api_key=env("AZURE_DALLE_API_KEY"),  
    api_version=env("AZURE_DALLE_API_VERSION")  
)  

def generate_image_with_dalle(prompt):  
    """DALL-E를 사용해 이미지를 생성"""  
    try:  
        print("DALL-E를 사용해 이미지를 생성합니다...")  
  
        # DALL-E API 호출  
        result = DALLE_CLIENT.images.generate(  
            model="dall-e-3",  # 사용할 DALL-E 모델  
            prompt=prompt,    # 생성할 이미지에 대한 프롬프트  
            n=1               # 생성할 이미지 개수  
        )  
  
        # 결과 처리  
        if result and result.data:  
            image_url = result.data[0].url  
            print("DALL-E 호출 성공! 생성된 이미지 URL:", image_url)  

            # 이미지 다운로드 및 저장
            save_image(image_url, prompt)
            
            return image_url  
        else:  
            print("DALL-E 호출 실패: 결과가 비어 있습니다.")  
            return None  
    except Exception as e:  
        print("DALL-E 호출 중 예외 발생:", str(e))  
        return None  
    
def save_image(image_url, prompt):
    """이미지를 다운로드하여 로컬에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()  

        # 이미지 폴더 생성
        os.makedirs("images", exist_ok=True)

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = os.path.join("images", f"{sanitized_filename}.png")

        with open(filename, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)

        print(f"이미지가 저장되었습니다: {filename}")

    except Exception as e:
        print(f"이미지 저장 중 오류 발생: {e}")

# 환경 변수 가져오기
account_name = env("STORAGE_ACCOUNT_NAME")  # 스토리지 계정명
account_key = env("STORAGE_ACCOUNT_KEY")  # 스토리지 계정 키
container_name = env("AI_CONTAINER_NAME")  # 컨테이너 이름

# Account Key를 사용하여 BlobServiceClient 생성
blob_service_client = BlobServiceClient(
    f"https://{account_name}.blob.core.windows.net",
    credential=account_key
)

def save_image_to_blob_storage(image_url, prompt):
    """이미지를 다운로드하여 Azure Blob Storage에 저장"""
    try:
        response = requests.get(image_url, stream=True)
        response.raise_for_status()

        # 파일명에서 특수문자 제거 및 최대 길이 제한
        sanitized_filename = re.sub(r'[<>:"/\\|?*]', '', prompt[:30]).strip()
        filename = f"{sanitized_filename}.png"

        # Blob Client 생성
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=filename)

        # 이미지 데이터 업로드 (파일 덮어쓰기 추가)
        blob_client.upload_blob(response.content, overwrite=True)

        # print(f"이미지가 Azure Blob Storage에 저장되었습니다: {filename}")

    except requests.exceptions.RequestException as req_err:
        print(f"이미지 다운로드 오류: {req_err}")

    except Exception as e:
        print(f"Azure Blob Storage에 이미지 저장 중 오류 발생: {e}")

def get_image_caption_and_tags(image_url):
    AZURE_COMPUTER_VISION_API_KEY = env("AZURE_COMPUTER_VISION_API_KEY")
    AZURE_COMPUTER_VISION_ENDPOINT = env("AZURE_COMPUTER_VISION_ENDPOINT")

    computervision_client = ComputerVisionClient(
        AZURE_COMPUTER_VISION_ENDPOINT,
        CognitiveServicesCredentials(AZURE_COMPUTER_VISION_API_KEY),
    )

    # Analyze the image using the Dense Caption feature
    analysis = computervision_client.describe_image(image_url)

    # Extract the caption information
    captions = []
    if analysis.captions:
        for caption in analysis.captions:
            print("Caption: ", caption.text)
            captions.append(caption.text)
    else:
        captions.append("No caption detected.")

    # Extract the tag information
    tags_result = computervision_client.tag_image(image_url)
    tags = [tag.name for tag in tags_result.tags]
    print("Tags: ", tags)

    return captions, tags

def generate_ai_curation(user_prompt, captions, tags):
    """
    한글로 각 스타일별 큐레이션을 생성하는 함수
    
    Args:
        user_prompt (str): 사용자 프롬프트
        captions (str): 이미지 설명
        tags (str): 태그들
    
    Returns:
        dict: 한글 스타일명과 큐레이션을 담은 딕셔너리
    """

    combined_text = f"프롬프트: {user_prompt}\n이미지 설명: {captions}\n태그: {tags}"

    # 스타일별 프롬프트 설정
    style_prompts = {
        "Emotional": """Explore the emotions and sentiments contained in this artwork in depth. Write lyrically, including the following elements:
            - The main emotions and atmosphere conveyed by the work
            - Emotional responses evoked by visual elements
            - The special emotions given by the moment in the work
            - Empathy and resonance that viewers can feel
            - Lyrical characteristics and poetic expressions of the work""",
        "Interpretive": """Analyze the meaning and artistic techniques of the work in depth. Interpret it by including the following elements:
            - The main visual elements of the work and their symbolism
            - The effects of composition and color sense
            - The artist's intention and message
            - Artistic techniques used and their effects
            - Philosophical/conceptual meaning conveyed by the work""",
        "Historical": """Analyze the work in depth in its historical and art historical context. Explain it by including the following elements:
            - The historical background and characteristics of the era in which the work was produced
            - Relationship with similar art trends or works
            - Position and significance in modern art history
            - Artistic/social impact of the work
            - Interpretation of the work in its historical context""",
        "Critical": """Provide a professional and balanced critique of the work. Evaluate it by including the following elements:
            - Technical completeness and artistry of the work
            - Analysis of creativity and innovation
            - Strengths and areas for improvement
            - Artistic achievement and limitations
            - Uniqueness and differentiation of the work""",
        "Narrative": """Unravel the work into an attractive story. Describe it by including the following elements:
            - Vivid description of the scene in the work
            - Relationship and story between the elements of appearance
            - Flow and changes in time in the work
            - Hidden drama and narrative in the scene
            - Context before and after that viewers can imagine""",
        "Trend": """Analyze the work from the perspective of contemporary art trends. Evaluate it by including the following elements:
            - Relevance to contemporary art trends
            - Digital/technological innovation elements
            - Meaning in the context of modern society/culture
            - Contact with the latest art trends
            - Implications for future art development"""
    }

    # 결과를 저장할 딕셔너리
    curations = {}

    # 각 스타일별로 큐레이션 생성
    for style, style_prompt in style_prompts.items():
        try:
            response = GPT_CLIENT.chat.completions.create(
                model="team6-o3-mini",
                messages=[
                    {"role": "system", "content": f"""You are an art curation expert. Provide a very detailed and professional analysis of the given work.
                    {style_prompt} The analysis should be written in a specific and persuasive manner,
                    and should clearly reveal the characteristics and value of the work from a professional perspective.
                    Please write a curation in Korean based on the following information."""},
                    {"role": "user", "content": combined_text}
                ]
            )
            curations[style] = response.choices[0].message.content
        except Exception as e:
            curations[style] = f"Error generating {style} curation: {str(e)}"

    return curations

def main():  
    """전체 워크플로 실행"""  
    user_input = input("이미지 생성 아이디어를 입력하세요: ").strip()  
    if not user_input:  
        print("입력값이 비어 있습니다. 유효한 입력값을 제공합니다.")  
        return  
  
    # Step 1: GPT-o3-mini를 사용해 프롬프트 생성  
    prompt = generate_prompt_with_gpt3o(user_input)  
    if not prompt:  
        print("프롬프트 생성 실패. 워크플로를 종료합니다.")  
        return  
  
    # Step 2: DALL-E를 사용해 이미지 생성  
    image_url = generate_image_with_dalle(prompt)  
    if not image_url:  
        print("이미지 생성 실패. 워크플로를 종료합니다.")  
        return  
    
    # Step 3: Azure Blob Storage에 이미지 저장
    if image_url:
        save_image_to_blob_storage(image_url, prompt)
    
    # Step 4 : Image Captions, Tags 생성
    captions, tags = get_image_caption_and_tags(image_url)

    # Step 5 : AI 큐레이션 생성
    results = generate_ai_curation(prompt, captions, tags)
    
    print("\n=== 최종 결과 ===")
    print(f"생성된 이미지가 'images/' 폴더에 저장되었습니다.")   
    print(f"생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.")  
    print("\n=== AI 큐레이션 결과 ===")
    
    for style, curation in results.items():
        print(f"\n=== {style} ===")
        print(curation)
        print("-" * 50)
  
if __name__ == "__main__":  
    main()
# Out:
# GPT-3o-mini를 사용해 프롬프트를 생성합니다...
# DALL-E를 사용해 이미지를 생성합니다...
# DALL-E 호출 성공! 생성된 이미지 URL: https://dalleproduse.blob.core.windows.net/private/images/4369a819-9455-4aa9-9b42-28bc8cf50281/generated_00.png?se=2025-02-13T03%3A25%3A24Z&sig=vmDZdDLNM6Pzb78G2e5U0iQEe9noSB6iygT%2Fz%2Fxg%2BhE%3D&ske=2025-02-14T01%3A52%3A27Z&skoid=09ba021e-c417-441c-b203-c81e5dcd7b7f&sks=b&skt=2025-02-07T01%3A52%3A27Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02
# 이미지가 저장되었습니다: images\A vibrant, close-up image of a.png
# Caption:  a bowl of food
# Tags:  ['food', 'cuisine', 'wok', 'dish', 'recipe', 'indoor', 'stir frying', 'meal', 'stew', 'bowl', 'vegetable', 'cooking', 'pan', 'soup', 'pot']
#
# === 최종 결과 ===
# 생성된 이미지가 'images/' 폴더에 저장되었습니다.
# 생성된 이미지가 Azure Blob Storage/ai-generated 컨테이너에 저장되었습니다.
#
# === AI 큐레이션 결과 ===
#
# === Emotional ===
# 이 작품은 감각적인 풍미와 시각적 유희가 어우러진 한 폭의 시처럼 다가옵니다. 붉게 타오르는 고추와 향신료가 어우러진 진한 고추 육수가 한가득 담긴 그릇은, 마치 우리의 마음 깊은 곳에서 얼어붙은 감정을 녹여내듯 따스하면서도 강렬한 느낌을 선사합니다. 작품은 따스한 분위기의 조명 아래, 한 폭의 동양화처럼 세밀하고 생생한 디테일로 표현된 매혹적인 음식의 정취를 전달하며, 시각적 감동과 함께 상상을 초월하는 향미의 교향곡을 예고합니다.
#
# 그릇에 담긴 음식들은 각각 고유의 색과 질감을 자랑하며, 서로 다른 재료들이 하나의 조화로운 앙상블을 이루는 모습은 우리에게 삶의 다양성과 공존의 아름다움을 은유적으로 일깨워줍니다. 육즙이 흐르고 재료의 온기가 얼굴 가득 번지는 것처럼, 관람자는 그 속에서 따뜻한 위로와 정감 어린 애정을 느낍니다. 한편, 따스한 목재 테이블과 전통 중국 도자기의 대조적 조화는 전통과 현대, 동서의 문화가 어우러져 생기는 특별한 감동을 불러일으킵니다.
#
# 특히 이 작품은 단순히 한 끼 식사가 아닌, 감성의 한 순간, 즉 일상의 소소한 행복과 정취를 소중히 담아내고 있습니다. 눈부신 색채와 섬세하게 표현된 증기의 소용돌이는 마치 사랑에 빠진 이의 떨림과도 같은 감정을 불러일으키며, 관람자가 그 자리에 서 있던 듯한 직접 체험의 느낌을 선사합니다. 그저 식감을 넘어서, 보는 이로 하여금 자신의 기억 속 잊혀진 따스한 순간들을 다시 한 번 음미하게 하는 작품입니다.
#
# 이 작품의 미학은 음식을 단순한 식재료의 집합체가 아니라, 이야기를 담은 한 편의 서사시로 승화시킵니다. 고요한 정취와 함께 매 순간 깊게 흐르는 감정의 물결은 우리 내면의 잔잔한 울림과 공감을 불러일으킵니다. 각 재료에서 풍기는 생명력과 따듯한 빛은 관람자로 하여금 삶의 작은 기쁨과 소중한 연결고리를 상기시키며, 그 자체가 하나의 기억으로 남습니다.
#
# 결국 이 작품은 단순한 음식 사진을 넘어, 정서적으로나 미학적으로도 깊은 울림을 주는 작품입니다. 색채의 풍부함, 질감의 다양성, 그리고 전통과 현대의 경계가 어우러진 구성이 우리에게 감성의 향연을 선사하며, 관람자로 하여금 열정과 위로, 그리고 사랑을 담은 그릇 속 이야기에 감동하게 만듭니다. 이러한 정교한 미학과 서정적인 표현은 이 작품이 단순한 시각적 즐거움을 넘어서, 인간 내면의 깊은 정서적 반응과 공감을 이끌어내는 예술 작품임을 단적으로 보여줍니다.
# --------------------------------------------------
#
# === Interpretive ===
# 해당 작품은 매혹적인 미각의 세계를 시각적으로 재현한 하이퍼 리얼리즘 푸드 포토그래피의 결정체로, 관객에게 단순한 음식 사진 이상의 감각적, 철학적 경험을 선사한다. 작품은 다층적인 시각적 요소와 정교한 색채, 그리고 풍부한 상징을 통해 예술가의 의도와 메시지를 은유적으로 전달하고 있다.
#
# 1. 주요 시각적 요소와 상징성
#    - 작품의 중심에는 매콤한 사천 마라탕 한 그릇이 자리 잡고 있다. 이 그릇은 단순한 음식 이상의 의미를 내포하며, 다양한 색깔의 재료들이 어우러진 모습은 다양성과 조화, 그리고 생명의 역동성을 상징한다.
#    - 각 재료—육류의 붉은 단맛, 부드러운 두부, 풍미 깊은 버섯, 신선한 잎채소, 그리고 탄력 있는 면발—는 물질적 풍요와 인간 삶의 다채로움을 은유적으로 표현하며, 식재료가 지닌 각기 다른 성질은 인간 사회의 다양한 개성과 연결된다.
#    - 전통 중국 도자기 그릇은 고유의 문화적 정체성을 나타내며, 음식이 단순한 섭취의 대상이 아닌 전통과 역사를 품은 예술 형식임을 시사한다.
#
# 2. 구성과 색채의 효과
#    - 작품은 주제인 음식의 본질에 집중하기 위해 클로즈업 구도를 사용, 관객을 한 솟아 오른 증기와 함께 진한 붉은 국물의 웅장함으로 끌어들인다.
#    - 따스한 조명은 음식의 윤곽과 질감을 부각시키며, 전체적으로 풍부하면서도 따뜻한 분위기를 조성해 음식을 단순한 시각적 대상으로 넘어, 감각적 체험의 매개체로 승화시킨다.
#    - 풍부한 붉은색 계열은 열정과 강렬한 맛, 그리고 생명의 에너지를 상징하며, 자연스러운 우드 톤의 배경은 전통적이면서도 소박한 매력을 더해준다.
#
# 3. 예술가의 의도와 메시지
#    - 이 작품은 단순한 음식 사진이 아니라, 음식에 스며든 문화와 정서를 시각적으로 전달하는 데 목적을 두고 있다. 예술가는 각각의 재료에 깃든 이야기와 전통, 그리고 그들이 어우러져 이루는 조화를 통해 ‘다양성 속의 통합’이라는 메시지를 제시한다.
#    - 또한, 고유의 전통을 이어가는 동시에 현대적인 감각을 더해, 과거와 현재가 공존하는 문화적 대화와 음식이 갖는 사회적 중요성을 재조명한다.
#
# 4. 사용된 예술적 기법과 그 효과
#    - 하이퍼 리얼리즘 기법은 섬세한 디테일과 실제감을 통해 관객이 마치 그 순간의 현장에 있는 듯한 몰입감을 선사한다. 질감, 색채, 증기의 움직임까지 세밀하게 묘사함으로써, 음식이 단순한 섭취대상이 아니라 한 편의 살아있는 예술 작품임을 강조한다.
#    - 인증된 내부 조명의 사용과 정교한 노출 컨트롤은 작품의 주인공인 국물의 깊은 색채와 음각을 부각시키며, 동시에 주변 재료의 다양한 질감과 색상을 조화롭게 연결한다.
#
# 5. 철학적·개념적 의미
#    - 작품은 우리의 일상 속에 숨어 있는 아름다움과, 단순한 음식이 담고 있는 풍부한 문화적, 철학적 의미를 재조명한다.
#    - ‘한 그릇의 음식’이라는 소재를 통해, 삶의 다양성과 유연성, 그리고 인간의 갈망—즉, 생명에 대한 열정과 소속감을 상징적으로 표현하고 있다.
#    - 또한, 전통과 현대, 단순과 복잡함 사이의 경계를 허물며, 음식이 단순히 영양을 공급하는 수단을 넘어 예술적, 문화적 커뮤니케이션의 매개체가 될 수 있음을 역설하고 있다.
#
# 종합하면, 본 작품은 색채와 구도, 그리고 세밀한 텍스처의 조합을 통해 관객으로 하여금 시각적 즐거움과 동시에 깊은 감성적, 철학적 성찰을 이끌어내는 걸작이다. 단순한 음식의 이미지가 아닌, 그 안에 담긴 다양한 이야기와 감성을 한층 정제된 예술적 언어로 풀어낸 이 작품은 현대 음식 예술의 새로운 지평을 열어놓았다고 평가할 수 있다.
# --------------------------------------------------
#
# === Historical ===
# 이 작품은 현대 디지털 미디어와 하이퍼 리얼리즘 기술이 결합되어 단순한 음식 사진 이상의 예술적 가치를 창출한 대표작이라고 할 수 있습니다. 작품에 묘사된 매운 사천식 마라탕 한 그릇은, 전통 중국 요리의 맛과 향, 그리고 문화적 정체성을 재현하는 동시에 현대 사회에서 음식 사진이 예술로 승화되는 과정을 상징합니다.
#
# 1. 역사적 배경 및 시대적 특성
# 이 작품은 디지털 사진기술의 비약적 발전과 함께 21세기 초반의 하이퍼 리얼리즘 흐름 속에 탄생하였습니다. 사진작가는 정교한 디테일과 생생한 색채 표현을 통해 전통 중국 잔칫상에서 느낄 수 있는 온기와 정통성을 재현하려 시도하였으며, 이는 글로벌화와 정보화 사회 속에서 흔들리는 전통과 현대의 조화를 모색하는 흐름과도 일맥상통합니다. 나아가, 농촌의 소박한 나무 테이블과 정교하게 제작된 중국 도자기 그릇 등 배경 요소들은 한국뿐 아니라 동아시아 문화권에서 오랜 세월 내려온 생활미학과 전통의 미덕을 다시 한 번 강조합니다.
#
# 2. 유사 미술 경향 및 작품과의 관계
# 현대 미술계에서는 식문화를 단순한 생존 행위가 아닌, 예술적 주제로 승화시키려는 시도들이 잇따르고 있습니다. 프랜시스 베이컨이나 레이첼 왈러 같은 작가들이 인체와 일상의 미학을 재해석한 것처럼, 본 작품은 음식이라는 소재를 통해 감각적 체험과 미적 즐거움을 선사합니다. 하이퍼 리얼리즘 기법을 채택함으로써 관객들은 마치 직접 그 앞에 앉아 따뜻한 향기와 맛을 느낄 수 있을 정도의 몰입감을 경험하게 되고, 이는 회화나 설치미술 등 전통적 미술 양식과는 달리 즉각적이고 직관적인 감각 자극을 전달합니다.
#
# 3. 현대 미술사에서의 위치와 의의
# 현대 음식 사진은 더 이상 단순한 요리법 소개를 넘어서, 문화적 정체성과 사회적 담론의 한 부분으로 자리매김하고 있습니다. 본 작품은 그 자체로 한 폭의 정물화와도 같으며, 사소해 보일 수 있는 일상적 소재를 통해 문화와 전통, 그리고 현대 사회의 소비 문화를 동시에 조명합니다. 디지털 기술을 통해 극한의 사실주의를 구현함으로써 미술사의 한 획을 그으며, 새로운 형태의 미학적 경험을 제공하는 동시에 전통 중국 요리의 세계적 확산과 문화적 가치를 재확인하는 역할을 합니다.
#
# 4. 예술적 및 사회적 영향
# 이 작품이 선사하는 시각적 향연은 관객들에게 감각적인 체험뿐 아니라, 음식이라는 매개체를 통한 문화 교류와 정체성의 회복을 상기시킵니다. 특히, 전통과 현대의 경계를 넘나드는 작업 방식은 글로벌 사회 속에서 다양한 문화들이 융합되는 현상을 반영하고 있으며, 소비자와 예술가, 문화 해설자 모두에게 새로운 담론의 장을 열어줍니다. 또한, 소셜 미디어와 디지털 플랫폼을 통해 널리 확산된 이 작품은 음식 사진이 단순한 기록을 넘어 하나의 예술 장르로 인정받는 데 기여하고 있습니다.
#
# 5. 역사적 맥락 속에서의 해석
# 역사적으로 음식은 단순한 생존의 도구가 아니라, 공동체의 정체성과 전통을 이어주는 매개체였습니다. 본 작품은 그 전통적 의미를 현대적 시각에서 재해석하며, 다채로운 재료들이 어우러져 하나의 조화를 이루는 모습은 사회 구성원 간의 연대감과 소통을 상징합니다. 한편, 사천식 마라탕의 매콤한 붉은 육수와 다채로운 재료의 조화는 역동적이며 다층적인 사회 구조를 은유하는 동시에, 전통과 혁신의 공존을 통해 새로운 문화적 패러다임을 제시합니다.
#
# 결론적으로, 이 작품은 전통 중국 요리의 미학과 현대 디지털 하이퍼 리얼리즘 기술이 결합하여 탄생한 예술적 성취라고 할 수 있습니다. 역사적, 사회적, 그리고 미학적 맥락 속에서 이 작품은 단순한 음식의 재현을 넘어, 전통과 현대, 동서양의 문화 융합이라는 복합적인 주제를 아우르는 상징적 가치를 지니고 있으며, 미술사와 현대 사회의 다양한 담론 속에서 지속적으로 논의될 만한 중요한 작품으로 평가받고 있습니다.
# --------------------------------------------------
#
# === Critical ===
# 이 작품은 강렬한 색채와 세밀한 디테일을 통해 감각적인 미식 체험을 생생하게 전달하는 하이퍼리얼리즘 음식 사진의 훌륭한 예라고 할 수 있습니다. 기술적인 완성도와 예술성에서 두드러지는 이 작품은 다음과 같은 여러 측면에서 평가할 수 있습니다.
#
# 1. 기술적 완성도와 예술성
# 작가는 따뜻한 주변 조명과 섬세한 하이라이트를 활용하여 중국 전통의 멋을 지닌 도자기 그릇에 담긴 매콤한 사천 마라탕의 붉은 육수를 생생하게 표현해냈습니다. 고해상도의 클로즈업 촬영 기법은 재료 하나하나의 텍스처와 색감을 세밀하게 포착해내어, 보는 이로 하여금 마치 직접 맛보고 냄새 맡는 듯한 몰입감을 선사합니다. 각 재료가 가진 독특한 광택과 질감은 디지털 렌더링의 정교함을 증명하며, 음식 사진 분야에서 기술적인 완성도를 높이는 뛰어난 예로 평가됩니다.
#
# 2. 창의성과 혁신성
# 전통적인 중국 요리의 매력을 현대적인 하이퍼리얼리즘 기법으로 재해석한 점은 작품의 큰 창의적 요소입니다. 재료의 배열과 조명의 사용은 단순한 음식 사진을 넘어서, 요리의 이야기를 시각적으로 풀어내는 데 성공했습니다. 특히, 따뜻한 조명 아래에서 빛나는 붉은 육수와 고소한 향을 연상케 하는 증기는 관객에게 감각적인 체험을 제공하며, 기존의 식도락 사진들과 차별화된 시각적 서사를 구축하는 혁신적 접근을 보여줍니다.
#
# 3. 강점 및 개선할 점
# 강점으로는 초점과 조명의 세밀한 조정, 그리고 재료의 다양성을 자연스럽게 담아낸 점을 들 수 있습니다. 마치 실내의 한 순간을 포착한 듯한 사실감 넘치는 표현은 관객에게 높은 몰입감을 주며, 음식의 매력을 다각도로 전달합니다. 다만, 고도로 사실적인 표현에서 오는 시각적 임팩트를 강조한 만큼, 때로는 관객이 음식의 다양한 질감과 맛을 상상하는 여지를 좀 더 열어두었으면 하는 아쉬움도 느껴집니다. 예를 들어, 주변 배경이나 추가적인 문맥 요소가 강화된다면 전체적인 스토리텔링 측면에서 더욱 풍부한 경험을 제공할 수 있을 것입니다.
#
# 4. 예술적 성취와 한계
# 작품은 음식 사진이라는 장르에서 극도의 리얼리즘을 추구하며 예술적 성취를 이뤄내고 있습니다. 특히, 전통 요리의 아름다움을 현대적인 시각으로 재해석한 점에서 높은 평가를 받을 만합니다. 한편, 극도로 포커스된 클로즈업 사진의 특성상 전체적인 환경이나 문화적 배경이 상대적으로 축소되어 전달되는 점은 한계로 볼 수 있습니다. 이러한 한계는 작품의 의도와 연출 방식에 따라 다르게 해석될 수 있으나, 관객에게 더 풍부한 맥락을 제공하기 위한 추가적인 시각적 요소가 고려된다면 더욱 완성도 높은 작품이 될 것입니다.
#
# 5. 독창성과 차별화
# 이 작품은 전통적인 사천 마라탕의 본질과 매운맛, 감각적인 시각적 요소를 현대 사진 기법으로 결합한 점에서 독창적인 면모를 드러냅니다. 재료의 다채로운 배열과 도자기 그릇의 전통미, 그리고 목재 테이블의 소박함이 조화를 이루어, 단순한 음식 이미지 이상의 이야기를 만들어내며 다른 음식 사진 작품들과 확연히 구별됩니다. 이는 관객에게 단순한 미식 경험을 넘어, 문화적 내러티브와 정서를 느낄 수 있는 기회를 제공하는 점에서 큰 가치가 있습니다.
#
# 종합적으로, 이 작품은 기술적 완성도와 창의적 시도에서 모두 높은 수준을 보여주며, 세밀한 디테일 속에 담긴 감각적인 미학을 통해 관객에게 강렬한 인상을 남깁니다. 미식 사진 예술 분야에서 혁신적인 접근과 전통의 재해석을 성공적으로 구현한 대표적인 작품이라 평가할 수 있겠습니다.
# --------------------------------------------------
#
# === Narrative ===
# 이 작품은 마치 한 폭의 수채화처럼 생생한 감각과 정열을 전달하는 음식 사진입니다. 그림처럼 디테일하게 묘사된 쌀쌀한 도자기 그릇에 가득 담긴 뜨거운 마라탕은, 붉은 고추와 각종 향신료가 혼합된 진한 붉은 국물의 온기를 한껏 느끼게 합니다. 그릇 속에는 육즙이 살아있는 고기 조각, 부드럽게 익은 두부, 싱그러운 잎채소와 촉촉한 면발, 그리고 고르지 않으면서도 어우러지는 다채로운 버섯들이 어우러져, 마치 풍부한 이야기를 품은 인물들이 한 자리에 모인 것처럼 각자 자신만의 매력을 드러내고 있습니다.
#
# 세밀하게 표현된 이 작품은 관람자를 향해 한 접시의 요리가 단순한 음식 이상의 이야기임을 암시합니다. 따뜻한 앰비언트 조명 아래, 국물에 반사되어 살아 움직이는 붉은 빛은 시간의 흐름을 상징하듯, 과거의 전통과 현대의 감각이 만나 하나의 순간으로 응집된 듯한 느낌을 줍니다. 이 붉은 광휘는 마치 한 편의 서사시의 클라이맥스를 연상시키며, 한 순간의 감정이 고조되는 동시에 숨겨진 이야기를 암시합니다.
#
# 작품 속의 모든 요소들은 서로 긴밀하게 얽혀 있으며, 각각의 재료는 그 나름의 역할을 맡고 있습니다. 고기는 오랜 시간 숙성된 깊은 풍미를 자랑하며, 두부는 부드러운 텍스처로 자연의 순수함을 상징합니다. 싱그러운 채소들은 생명의 활력을, 면발은 손맛과 정성이 깃든 가족의 기억을 떠올리게 합니다. 그리고 이 모든 것이 하나의 작품으로 어우러져, 관람자에게 단순한 식사의 모습을 넘어 삶의 다채로운 맛과 여운을 전달합니다.
#
# 작품의 시간의 흐름 또한 주목할 만합니다. 사진 속 김이 모락모락 피어오르는 순간은 마치 요리가 막 완성되어 따뜻한 감성이 전해지는 동시에, 그 향을 따라 과거의 전통적인 요리법과 현대적 감각이 서로 대화하는 모습처럼 느껴집니다. 뜨거운 국물의 온기와 향긋한 김은 관람자로 하여금 이 음식이 만들어지기 전의 기쁨과 열정, 그리고 그 이후 식탁에 앉은 이들의 이야기까지 상상하게 합니다.
#
# 이 작업은 단순히 시각적 매력을 넘어, 음식이라는 매개체를 통해 삶의 깊이와 인간의 정서를 드러냅니다. 관람자는 이 한 컵의 마라탕을 통해 전통 중국 요리의 역사와 현대적 감각이 융합된 새로운 서사를 마주하며, 그 속에서 숨겨진 드라마와 인간미를 발견하게 됩니다. 작품은 식재료 하나하나에 독특한 스토리가 있음을 암시하면서도, 동시에 전체적인 조화와 균형을 통해 한 편의 흥미로운 내러티브를 펼쳐 보입니다.
#
# 이처럼 작가는 맛과 멋, 전통과 현대를 한데 녹여낸 시각적 서사로 관람자에게 단순한 미각적 향연을 넘어, 감성적 기억과 문화적 깊이를 동시에 경험할 수 있는 특별한 순간을 선사합니다. 이는 요리 예술의 본질을 재해석하고, 한 끼의 식사가 어떻게 인간의 역사와 정서를 담아내는지에 대한 새로운 이해를 제안하는 귀중한 작품이라 할 수 있습니다.
# --------------------------------------------------
#
# === Trend ===
# 이 작품은 현대 미술의 최신 경향과 디지털 기술의 혁신적 활용을 절묘하게 결합한 예로 평가할 수 있습니다. 프롬프트에서 제시된 '매우 생생한 초근접 촬영'이라는 표현처럼, 작가는 일상의 한 장면인 음식을 단순한 소비 대상이 아니라 심미적이고 문화적인 경험으로 승화시킵니다.
#
# 첫째, 이 작품은 현대 미술의 디지털 렌더링 기술과 하이퍼 리얼리즘 스타일을 적극적으로 반영합니다. 최신 디지털 아트 트렌드는 정확하고 극적인 묘사를 통해 관람자에게 현실 이상의 감각적 놀라움을 선사하는데, 이 작품 역시 세밀한 디테일과 따뜻한 조명을 통해 음식의 질감, 컬러, 그리고 증기로 표현되는 생동감을 극대화합니다. 전통적인 음식 사진을 넘어 미술 작품으로 승화시키는 작가의 의도는 기술과 예술이 만나는 지점에서 새로운 미적 경험을 창조하는 현대 미술의 혁신을 상징합니다.
#
# 둘째, 이 작품은 전통과 현대의 만남이라는 주제를 내포합니다. 칠면조의 전통적인 중국 도자기 그릇, 소박한 목재 테이블, 그리고 정통의 '마라탕' 같은 음식은 동서양의 전통적 미적 요소와 더불어, 디지털 기술을 통한 현대적 재해석을 보여줍니다. 이는 글로벌 문화의 융합과 동시에 전통적 가치의 현대적 재해석이라는 현대 사회의 중요한 이슈를 반영합니다. 음식은 단순한 영양 공급원이 아닌, 문화와 정체성을 담은 예술적 언어로 다시 태어난 것입니다.
#
# 셋째, 이 작품은 현대 사회에서의 소비문화와 디지털화된 이미지 매개체의 역할을 논의할 수 있는 중요한 사례입니다. 미디어를 통해 확산된 이미지들은 단순한 기록물에서 벗어나 사회적 담론과 정체성 형성에 큰 영향을 미치는데, 이 작품 역시 관람자로 하여금 음식이라는 일상적 소재 속에 숨겨진 미적 가치와 문화적 의미를 재고하게 만듭니다. 특히, 따뜻한 조명과 세밀한 묘사는 현대 사회의 불안정한 환경 속에서도 인간이 찾고자 하는 위안과 정체성, 그리고 소통의 의미를 상기시킵니다.
#
# 마지막으로, 이 작품은 미래 미술 발전에 많은 시사점을 제공합니다. 디지털 기술을 통한 작품의 재현 방식과 하이퍼 리얼리즘이라는 기법은 앞으로의 미술이 어떻게 전통적인 소재에도 혁신적인 표현 방식을 도입하여 새로운 미적 경험을 창출할 수 있는지를 보여줍니다. 이는 단순한 이미지 재현을 넘어, 관람자와의 감성적, 지적 교류를 증진시키는 매개체로서의 미술의 역할을 재정의하는 데 기여합니다.
#
# 요약하자면, 이 작품은 전통적인 음식 이미지를 디지털 혁신과 현대 미학의 관점에서 재조명한 결과물입니다. 초근접 촬영과 하이퍼 리얼리즘 기법을 통해 관람자에게 생동감과 감각적 체험을 선사하며, 동시에 전통과 현대, 문화와 기술의 융합이라는 복합적인 메시지를 전달합니다. 이러한 다층적 의미와 혁신적 표현은 현대 미술의 발전 방향과 향후 예술적 탐구에 중요한 통찰을 제공하며, 미래 미술이 어떠한 방향으로 나아갈지를 예견하게 합니다.
# --------------------------------------------------
